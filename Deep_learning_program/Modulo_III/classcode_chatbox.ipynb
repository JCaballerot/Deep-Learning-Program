# %% [markdown]
# <a href="https://colab.research.google.com/github/JCaballerot/Deep_learning_program/blob/main/Deep_learning_program/Modulo_III/classcode_chatbox.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Using Blenderbot Chatbox

# %%
# !nvidia-smi
# Out:
# Sat Oct  2 01:33:15 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   39C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/facebookresearch/ParlAI.git
# Out:
# Cloning into 'ParlAI'...
# remote: Enumerating objects: 41452, done.
# remote: Counting objects: 100% (1057/1057), done.
# remote: Compressing objects: 100% (649/649), done.
# remote: Total 41452 (delta 524), reused 760 (delta 386), pack-reused 40395
# Receiving objects: 100% (41452/41452), 88.98 MiB | 32.93 MiB/s, done.
# Resolving deltas: 100% (29401/29401), done.

# %%
cd ParlAI/
# Out:
# /content/ParlAI

# %%
# !python setup.py develop
# Out:
# running develop
# running egg_info
# creating parlai.egg-info
# writing parlai.egg-info/PKG-INFO
# writing dependency_links to parlai.egg-info/dependency_links.txt
# writing entry points to parlai.egg-info/entry_points.txt
# writing requirements to parlai.egg-info/requires.txt
# writing top-level names to parlai.egg-info/top_level.txt
# writing manifest file 'parlai.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'parlai.egg-info/SOURCES.txt'
# running build_ext
# Creating /usr/local/lib/python3.7/dist-packages/parlai.egg-link (link to .)
# Adding parlai 1.5.0 to easy-install.pth file
# Installing parlai script to /usr/local/bin
#
# Installed /content/ParlAI
# Processing dependencies for parlai==1.5.0
# Searching for jsonlines
# Reading https://pypi.org/simple/jsonlines/
# ...
# Best match: jsonlines 2.0.0
# Processing jsonlines-2.0.0-py3-none-any.whl
# Installing jsonlines-2.0.0-py3-none-any.whl to /usr/local/lib/python3.7/dist-packages
# ...

# %%
# !pip install 'git+https://github.com/rsennrich/subword-nmt.git#egg=subword-nmt'
# Out:
# ...
#   Cloning https://github.com/rsennrich/subword-nmt.git to /tmp/pip-install-l92d3cwp/subword-nmt_949fe7fb82a9481c83db838965aaf189
#   Running command git clone -q https://github.com/rsennrich/subword-nmt.git /tmp/pip-install-l92d3cwp/subword-nmt_949fe7fb82a9481c83db838965aaf189

# %% [markdown]
# ## Facebook BlenderBot

# %%
# !pip install iopath

# %%
# !python /content/ParlAI/parlai/scripts/interactive.py -t blended_skill_talk -mf zoo:blender/blender_3B/model
# Out:
#                                  /@&%###%&&@@#
#                       .,*/((((##@@@&%%#%%&&@@@&%%#/*.
#              #@@&&&%%%%##(((///*****//(((###%%%&&&@@@@@&&%#%%#.
#          .%&@@@@@&&&%%%####((((////((((####%%%&&&@@@@@&&%%#%%####,
#            ./,,#(//**,,.....,,,,***////((((########%%%%%%%%###(((
#               /*(//**,,,....,,,,***////((((########%%%%%%%%###(#%*
#                (*,...      ...,,,***//////((((((///////(/*...,/#@@@(
#                **,,..         ...,,,,,,,,,,........,,*///*...*(#@@@@&&*
#                ./,,..          ...,,,,,,,,,........,,*//*,...*#/,,,,,/%#
#                 (*,..          ...,,,,,,,,,........,,*//*,..,/(      .,#(
#                 **,..          ...,,,,,,,,,.........,*//*,..,((       .,(#
#                  /*,..          ....,,,,,,,.....  ..,***,,,,(#         ..#&
#                  **,..          ....,,,,,,,....   ..,***,,,*#.         .,%@
#                  ./,...       B l e n d e r B o t ...***,,,*#          .*%@
# ...
